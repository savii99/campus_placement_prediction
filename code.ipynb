# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the dataset
df = pd.read_csv(r"Placement_Data_Full_Class.csv")

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.shape
# Out:
# (215, 15)

# %%
#checking null values.
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#storing categorical and numerical data in diff variable based on their datatypes
catvar =list(df.select_dtypes(include= ["object"]).columns)

# %%
catvar
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
numeric =list(df.select_dtypes(include= ['int32','float32',"float64","int64"]).columns)

# %%
numeric
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
df["salary"].mean()
# Out:
# 288655.4054054054

# %%
df["salary"].mode()[0]
# Out:
# 300000.0

# %%
df["salary"].median()
# Out:
# 265000.0

# %%
#making temporary salary columns:(mean,median , mode)
df["salary_mean"]= df["salary"].fillna(df["salary"].mean())
df["salary_mode"]=df["salary"].fillna(df["salary"].mode()[0])
df["salary_median"]= df["salary"].fillna(df["salary"].median())

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#      salary_mean  salary_mode  salary_median
# 0  270000.000000     270000.0       270000.0
# ...

# %%
# made function for ploting salary col and temp salary cols
def plotdistplot(cols):
    plt.figure(figsize = (15,7))
    sns.distplot(df['salary'], kde = True, hist = False , label = 'Actual salary', color ="black")
    sns.distplot(df[cols], kde = True, hist = False , label = 'cols salary', color = "red")

# %%
salary_list = ['salary_mean', 'salary_mode', 'salary_median']
for col in salary_list:
    plotdistplot(col)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25196\3459616720.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['salary'], kde = True, hist = False , label = 'Actual salary', color ="black")
# C:\Users\HP\AppData\Local\Temp\ipykernel_25196\3459616720.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#conclusion: mean value shows relevant result for null value. so we drop the temp columns

df = df.drop(columns=['salary_mean', 'salary_mode', 'salary_median'] , axis = 1)

# %%
#filling the null values by mean value
df['salary']= df['salary'].fillna(df['salary'].mean())

# %%
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
sns.countplot(df, x=df["status"])
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
def valuecount(col):
    return dict(df[col].value_counts())

def getcountplot(col):

    sns.countplot(df,x=df[col], palette = 'plasma')
    
    plt.show()

for col in catvar:
    print(f'countplot for feature {col} is shown here:')
    getcountplot(col)
    print('='*75)
# Out:
# countplot for feature gender is shown here:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25196\3084431126.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=df[col], palette = 'plasma')
# ...
# countplot for feature ssc_b is shown here:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25196\3084431126.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=df[col], palette = 'plasma')
# ...
# countplot for feature hsc_b is shown here:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25196\3084431126.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
getfinaldict = {}

for col in catvar:
    getfinaldict[col]= valuecount(col)
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
#top science students placed

df[(df["degree_t"]=='Sci&Tech') & (df["status"]== "Placed")].sort_values(by = "salary", ascending= False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0    150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1     77     78      M  64.00   Others  80.00   Others  Science     65.00
# 2    163    164      M  63.00   Others  67.00   Others  Science     64.00
# 3    174    175      M  73.24   Others  50.83   Others  Science     64.27
# 4     53     54      M  80.00   Others  70.00   Others  Science     72.00
#
#    degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Sci&Tech    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 1  Sci&Tech    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 2  Sci&Tech     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 3  Sci&Tech    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 4  Sci&Tech     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %%
#top commerce student placed

df[(df["degree_t"]=='Comm&Mgmt') & (df["status"]== "Placed")].sort_values(by = "salary", ascending= False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    119    120      M   60.8  Central   68.4  Central  Commerce      64.6
# 1    177    178      F   73.0  Central   97.0   Others  Commerce      79.0
# 2      4      5      M   85.8  Central   73.6  Central  Commerce      73.3
# 3     95     96      M   73.0  Central   78.0   Others  Commerce      65.0
# 4    210    211      M   80.6   Others   82.0   Others  Commerce      77.6
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2  Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3  Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4  Comm&Mgmt     No    91.00        Mkt&Fin  74.49  Placed  400000.0

# %%
#max salary and min salary
#oberved salary: max =940000 and min = 200000

df[(df["salary"]==max(df['salary'])) | (df['salary']==min(df['salary']))].sort_values(by= 'salary', ascending = False).reset_index()
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 1      1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2     15     16      F  65.00  Central  75.00  Central  Commerce     69.00
# 3     44     45      F  77.00   Others  73.00   Others  Commerce     81.00
# 4     50     51      F  75.20  Central  73.20  Central   Science     68.40
# 5    107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 6    135    136      F  72.00  Central  56.00   Others   Science     69.00
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28  Placed  200000.0
# 2  Comm&Mgmt    Yes    72.00        Mkt&Fin  64.66  Placed  200000.0
# 3  Comm&Mgmt    Yes    89.00        Mkt&Fin  69.70  Placed  200000.0
# ...

# %%
#student having more than avg salary in science dept

df[(df['degree_t']=='Sci&Tech') & (df['salary']> df['salary'].mean())].sort_values(by= 'salary',ascending= False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0    150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1    174    175      M  73.24   Others  50.83   Others  Science     64.27
# 2     77     78      M  64.00   Others  80.00   Others  Science     65.00
# 3    163    164      M  63.00   Others  67.00   Others  Science     64.00
# 4     53     54      M  80.00   Others  70.00   Others  Science     72.00
#
#    degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Sci&Tech    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 1  Sci&Tech    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 2  Sci&Tech    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 3  Sci&Tech     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 4  Sci&Tech     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %%
#student having more than avg salary in commerce dept


df[(df['degree_t']=='Comm&Mgmt') & (df['salary']> df['salary'].mean())].sort_values(by= 'salary',ascending= False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    119    120      M  60.80  Central  68.40  Central  Commerce      64.6
# 1    177    178      F  73.00  Central  97.00   Others  Commerce      79.0
# 2      4      5      M  85.80  Central  73.60  Central  Commerce      73.3
# 3     95     96      M  73.00  Central  78.00   Others  Commerce      65.0
# 4     85     86      F  83.84   Others  89.83   Others  Commerce      77.2
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2  Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3  Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4  Comm&Mgmt    Yes    78.74        Mkt&Fin  76.18  Placed  400000.0

# %%
df[['status',"degree_t"]].groupby(['status', 'degree_t']).size()
# Out:
# status      degree_t
# Not Placed  Comm&Mgmt     43
#             Others         6
#             Sci&Tech      18
# Placed      Comm&Mgmt    102
#             Others         5
#             Sci&Tech      41
# dtype: int64

# %%
df[['status',"degree_t"]].groupby(['status', 'degree_t']).size().plot(kind= 'bar' , color = "pink")

#observation :max comm&mngt student are placed
# Out:
# <Axes: xlabel='status,degree_t'>

# %%
df[["specialisation",'status']].groupby(['specialisation','status']).size()
# Out:
# specialisation  status
# Mkt&Fin         Not Placed    25
#                 Placed        95
# Mkt&HR          Not Placed    42
#                 Placed        53
# dtype: int64

# %%
#countplot of specialisation student who are placed

df[["specialisation",'status']].groupby(['specialisation','status']).size().plot(kind= 'bar' , color = "blue")
# Out:
# <Axes: xlabel='specialisation,status'>

# %%
df[["gender",'status']].groupby(['gender','status']).size()
# Out:
# gender  status
# F       Not Placed     28
#         Placed         48
# M       Not Placed     39
#         Placed        100
# dtype: int64

# %%
#gender countplot of whom placed

df[["specialisation",'status']].groupby(['specialisation','status']).size().plot(kind = "pie", autopct = "%1.0f%%")
# Out:
# <Axes: >

# %%
#max salary of female
#df[(df['gender']=="F") & (df['salary']== max(df['salary']))]

temp= df[df['gender']=="F"]
temp[temp['salary']==max(temp['salary'])]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 177    178      F   73.0  Central   97.0  Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 177  Comm&Mgmt    Yes     89.0        Mkt&Fin  70.81  Placed  650000.0

# %%
df[["hsc_s",'status']].groupby(['hsc_s','status']).size()
# Out:
# hsc_s     status
# Arts      Not Placed     5
#           Placed         6
# Commerce  Not Placed    34
#           Placed        79
# Science   Not Placed    28
#           Placed        63
# dtype: int64

# %%
df[["hsc_s",'status']].groupby(['hsc_s','status']).size().plot(kind = "pie", autopct = "%1.0f%%")
# Out:
# <Axes: >

# %% [markdown]
# Encoding

# %%
catvar
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
df.head(5)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
catvar
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

for column in df[catvar]:
    df[column] = label_encoder.fit_transform(df[column])



print(df)
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        1       1  67.00      1  91.00      1      1     58.00         2
# 1        2       1  79.33      0  78.33      1      2     77.48         2
# 2        3       1  65.00      0  68.00      0      0     64.00         0
# 3        4       1  56.00      0  52.00      0      2     52.00         2
# 4        5       1  85.80      0  73.60      0      1     73.30         0
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    211       1  80.60      1  82.00      1      1     77.60         0
# 211    212       1  58.00      1  60.00      1      2     72.00         2
# 212    213       1  67.00      1  67.00      1      1     73.00         0
# 213    214       0  74.00      1  66.00      1      1     58.00         0
# 214    215       1  62.00      0  58.00      1      2     53.00         0
#
#      workex  etest_p  specialisation  mba_p  status         salary
# ...

# %%
df.drop(columns = "sl_no" , axis = 1 , inplace = True)

# %%
df
# Out:
#      gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0         1  67.00      1  91.00      1      1     58.00         2       0
# 1         1  79.33      0  78.33      1      2     77.48         2       1
# 2         1  65.00      0  68.00      0      0     64.00         0       0
# 3         1  56.00      0  52.00      0      2     52.00         2       0
# 4         1  85.80      0  73.60      0      1     73.30         0       0
# ..      ...    ...    ...    ...    ...    ...       ...       ...     ...
# 210       1  80.60      1  82.00      1      1     77.60         0       0
# 211       1  58.00      1  60.00      1      2     72.00         2       0
# 212       1  67.00      1  67.00      1      1     73.00         0       1
# 213       0  74.00      1  66.00      1      1     58.00         0       0
# 214       1  62.00      0  58.00      1      2     53.00         0       0
#
#      etest_p  specialisation  mba_p  status         salary
# ...

# %% [markdown]
# # EDA FOR NUMERIC DATA

# %%
numeric
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
numeric[1:]
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
import scipy.stats as stats

def getplot(df,col):
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color = "orange")

    plt.subplot(1,3,2)
    stats.probplot(df[col], dist="norm",plot=plt)

    plt.subplot(1,3,3)
    sns.boxplot(df[col], color="orange")

    plt.show()
    
for col in numeric[1:] :
    print(f"Distribution plot for col {col} are shown here:")
    getplot(df,col)
    print("="*75)
# Out:
# Distribution plot for col ssc_p are shown here:
# ...
# Distribution plot for col hsc_p are shown here:
# ...
# Distribution plot for col degree_p are shown here:
# ...
# Distribution plot for col etest_p are shown here:
# ...
# Distribution plot for col mba_p are shown here:
# ...
# Distribution plot for col salary are shown here:
# ...

# %% [markdown]
# # FEATURE SELECTION

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot = True, cmap="plasma")
# Out:
# <Axes: >

# %%
'''
we will drop the salary column as well
because after getting the placement we will get to know the salary right!
'''

data=df.copy()
test= data['status']
train = data.drop(['status','salary'],axis = 1)
train.head(5)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
# 2       1  65.00      0  68.00      0      0     64.00         0       0
# 3       1  56.00      0  52.00      0      2     52.00         2       0
# 4       1  85.80      0  73.60      0      1     73.30         0       0
#
#    etest_p  specialisation  mba_p
# 0     55.0               1  58.80
# 1     86.5               0  66.28
# 2     75.0               0  57.80
# 3     66.0               1  59.43
# 4     96.8               0  55.50

# %%
##Extratrees classifier
from sklearn.ensemble import ExtraTreesClassifier
ec = ExtraTreesClassifier()
ec.fit(train,test)
# Out:
# ExtraTreesClassifier()

# %%
featbar= pd.Series(ec.feature_importances_,index =train.columns)
featbar.nlargest(7).plot(kind='barh')
# Out:
# <Axes: >

# %%
featbar.nlargest(7).plot(kind='pie',autopct = '%1.0f%%',figsize = (15,7))
# Out:
# <Axes: >

# %%
#mutual classifier

from sklearn.feature_selection import mutual_info_classif
mc = mutual_info_classif(train,test)
ax= pd.Series(mc,index=train.columns)
ax.nlargest(7).plot(kind='barh')
# Out:
# <Axes: >

# %%
pd.Series(mc,index=train.columns).plot(kind='pie',autopct='%1.0f%%',figsize=(15,7))
# Out:
# <Axes: >

# %%
'''
Selecting the top 10 contributing features in both cases
and then we will do the intersection of both the results
so that we will get atleast top 5 most contributing features!
'''


featcol=list(featbar.nlargest(10).index)
mutclasif = list(ax.nlargest(10).index)
commomcols= list(set(featcol).intersection(set(mutclasif)))
print(commomcols)
# Out:
# ['degree_p', 'mba_p', 'hsc_p', 'gender', 'specialisation', 'ssc_p', 'hsc_b', 'workex']

# %%
#selecting the commom cols and will do training on these cols!
#these cols were selected as a nlargest result of 2 feature selection techniques!

train = df[commomcols]
train.head()
# Out:
#    degree_p  mba_p  hsc_p  gender  specialisation  ssc_p  hsc_b  workex
# 0     58.00  58.80  91.00       1               1  67.00      1       0
# 1     77.48  66.28  78.33       1               0  79.33      1       1
# 2     64.00  57.80  68.00       1               0  65.00      0       0
# 3     52.00  59.43  52.00       1               1  56.00      0       0
# 4     73.30  55.50  73.60       1               0  85.80      0       0

# %%
'''
from the above Df we notice that gender, specialisation, degree_t,workex are the categorical columns
 and they make sense isn't it? for any placement drive
students are first filtered on basis of their boards, 
sem scores which in this case are (mba_p,ssc_p,degree.p,hsc_p)
 and then workexperience also matters a lot!, 
 then specialisation as well,gender is also because now-a-days few companies focus on women empowerment, so yes, all the features make perfect sense!
 '''
# Out:
# "\nfrom the above Df we notice that gender, specialisation, degree_t,workex are the categorical columns\n and they make sense isn't it? for any placement drive\nstudents are first filtered on basis of their boards, \nsem scores which in this case are (mba_p,ssc_p,degree.p,hsc_p)\n and then workexperience also matters a lot!, \n then specialisation as well,gender is also because now-a-days few companies focus on women empowerment, so yes, all the features make perfect sense!\n "

# %%
train.head()
# Out:
#    degree_p  mba_p  hsc_p  gender  specialisation  ssc_p  hsc_b  workex
# 0     58.00  58.80  91.00       1               1  67.00      1       0
# 1     77.48  66.28  78.33       1               0  79.33      1       1
# 2     64.00  57.80  68.00       1               0  65.00      0       0
# 3     52.00  59.43  52.00       1               1  56.00      0       0
# 4     73.30  55.50  73.60       1               0  85.80      0       0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, RandomizedSearchCV,cross_val_score
from sklearn import metrics

# %%
X_train,x_test,Y_train,y_test = train_test_split(train,test,test_size=0.2)

# %%
X_train.shape,x_test.shape
# Out:
# ((172, 8), (43, 8))

# %%
dc= DecisionTreeClassifier()
dc.fit(X_train,Y_train)
plt.figure(figsize=(16,9))
tree.plot_tree(dc,filled= True,class_names=['Not places','placed'],feature_names=train.columns)
# Out:
# [Text(0.42410714285714285, 0.9444444444444444, 'ssc_p <= 62.5\ngini = 0.435\nsamples = 172\nvalue = [55, 117]\nclass = placed'),
#  Text(0.17857142857142858, 0.8333333333333334, 'hsc_p <= 58.5\ngini = 0.414\nsamples = 58\nvalue = [41, 17]\nclass = Not places'),
#  Text(0.14285714285714285, 0.7222222222222222, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = Not places'),
#  Text(0.21428571428571427, 0.7222222222222222, 'degree_p <= 64.405\ngini = 0.5\nsamples = 34\nvalue = [17, 17]\nclass = Not places'),
#  Text(0.14285714285714285, 0.6111111111111112, 'mba_p <= 58.37\ngini = 0.434\nsamples = 22\nvalue = [15, 7]\nclass = Not places'),
#  Text(0.10714285714285714, 0.5, 'hsc_p <= 63.5\ngini = 0.486\nsamples = 12\nvalue = [5, 7]\nclass = placed'),
#  Text(0.07142857142857142, 0.3888888888888889, 'ssc_p <= 52.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = placed'),
#  Text(0.03571428571428571, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not places'),
# ...

# %%
costpath = dc.cost_complexity_pruning_path(train,test)
ccp_alpha,impurities= costpath.ccp_alphas,costpath.impurities

# %%
ccp_alpha
# Out:
# array([0.        , 0.00413437, 0.00422833, 0.00422833, 0.00426357,
#        0.00434109, 0.00473435, 0.00620897, 0.00697674, 0.01178068,
#        0.01185342, 0.0119541 , 0.01434505, 0.01522199, 0.01963357,
#        0.04354394, 0.14599558])

# %%
impurities
# Out:
# array([0.        , 0.00826873, 0.01672539, 0.02518205, 0.03370918,
#        0.04239136, 0.05186006, 0.07669594, 0.08367268, 0.14257607,
#        0.15442948, 0.19029178, 0.20463683, 0.21985882, 0.23949239,
#        0.28303633, 0.42903191])

# %%
modellist=[]
for alpha in ccp_alpha:
    dc= DecisionTreeClassifier(ccp_alpha=alpha)
    dc.fit(X_train,Y_train)
    modellist.append(dc)

# %%
modellist
# Out:
# [DecisionTreeClassifier(),
#  DecisionTreeClassifier(ccp_alpha=0.004134366925064599),
#  DecisionTreeClassifier(ccp_alpha=0.004228329809725159),
#  DecisionTreeClassifier(ccp_alpha=0.004228329809725159),
#  DecisionTreeClassifier(ccp_alpha=0.004263565891472868),
#  DecisionTreeClassifier(ccp_alpha=0.004341085271317831),
#  DecisionTreeClassifier(ccp_alpha=0.004734354320287392),
#  DecisionTreeClassifier(ccp_alpha=0.006208968510070101),
#  DecisionTreeClassifier(ccp_alpha=0.0069767441860465115),
#  DecisionTreeClassifier(ccp_alpha=0.011780676876536203),
#  DecisionTreeClassifier(ccp_alpha=0.011853417899929527),
#  DecisionTreeClassifier(ccp_alpha=0.011954099636020114),
#  DecisionTreeClassifier(ccp_alpha=0.014345049677053412),
#  DecisionTreeClassifier(ccp_alpha=0.015221987315010573),
#  DecisionTreeClassifier(ccp_alpha=0.019633565458658242),
#  DecisionTreeClassifier(ccp_alpha=0.043543939616998095),
#  DecisionTreeClassifier(ccp_alpha=0.14599558360017156)]

# %%
train_score = [clf.score(X_train,Y_train)for clf in modellist]
test_score= [clf.score(x_test,y_test)for clf in modellist]

plt.xlabel('alpha_value')
plt.ylabel("accuracy")
plt.plot(ccp_alpha,train_score,label="train score",marker="*",color= "blue")
plt.plot(ccp_alpha,test_score,label="test score",marker="D",color= "green")
plt.legend()
plt.show()

# %%
dc= DecisionTreeClassifier(ccp_alpha=0.0196)
dc.fit(X_train,Y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(dc,filled = True,class_names=["Not_placed","Placed"],feature_names=train.columns)
# Out:
# [Text(0.5, 0.9, 'ssc_p <= 62.5\ngini = 0.435\nsamples = 172\nvalue = [55, 117]\nclass = Placed'),
#  Text(0.2, 0.7, 'hsc_p <= 58.5\ngini = 0.414\nsamples = 58\nvalue = [41, 17]\nclass = Not_placed'),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = Not_placed'),
#  Text(0.3, 0.5, 'degree_p <= 64.405\ngini = 0.5\nsamples = 34\nvalue = [17, 17]\nclass = Not_placed'),
#  Text(0.2, 0.3, 'mba_p <= 58.37\ngini = 0.434\nsamples = 22\nvalue = [15, 7]\nclass = Not_placed'),
#  Text(0.1, 0.1, 'gini = 0.486\nsamples = 12\nvalue = [5, 7]\nclass = Placed'),
#  Text(0.3, 0.1, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Not_placed'),
#  Text(0.4, 0.3, 'gini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Placed'),
#  Text(0.8, 0.7, 'degree_p <= 65.8\ngini = 0.215\nsamples = 114\nvalue = [14, 100]\nclass = Placed'),
#  Text(0.7, 0.5, 'mba_p <= 68.83\ngini = 0.393\nsamples = 41\nvalue = [11, 30]\nclass = Placed'),
# ...

# %% [markdown]
# HYPERPARAMETER TUNING

# %%
params={
    "Randomforest":{
        "model": RandomForestClassifier(),
        "params":{
            'n_estimators':[int(x)for x in np.linspace(start=1,stop=1200,num=10)],
            'max_depth':[int(x)for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':["auto","sqrt"],
            "ccp_alpha":[0.0185,0.0190,0.0196,0.0200],

        }
    },
    'logistic':{
        'model': LogisticRegression(),
        'params':{
            "penalty":["l1","l2","elasticnet"],
            "C":[0.25,0.50,0.75,1.0],
            "tol":[1e-10,1e-5,1e-4,1e-3,0.025,0.25,0.50],
            'solver':['lbfgs','liblinear','saga','newton-cg'],
            'multi_class':['auto','ovr','multinomial'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
            
        }
    },
    'D-tree':{
        'model': DecisionTreeClassifier(),
        'params':{
            'criterion':['gini','entropy'],
            'splitter':['best','random'],
            'min_samples_split':[1,2,35,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':["auto",'sqrt'],
            'ccp_alpha':[0.0185,0,0.190,0.0195,0.0200],

        }

    },
    'SVM':{
        'model':SVC(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear','poly','sigmoid','rbf'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    }
}

# %%
scores =[]
for model_name,mp in params.items():

    clf=RandomizedSearchCV(mp['model'],param_distributions=mp['params'],cv=5,n_iter=10,n_jobs=-1,scoring='accuracy')
    clf.fit(X_train,Y_train)
    scores.append({
        'model_name':model_name,
        'best_score':clf.best_score_,
        'best_estimator': clf.best_estimator_
    })
# Out:
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py", line 638, in _validate_params
# ...

# %%
scores_df= pd.DataFrame(data= scores,columns=['model_name','best_score',"best_estimator"])
scores_df.head()
# Out:
#      model_name  best_score                                     best_estimator
# 0  Randomforest    0.854118  (DecisionTreeClassifier(ccp_alpha=0.0185, max_...
# 1      logistic    0.853950  LogisticRegression(max_iter=84, multi_class='o...
# 2        D-tree    0.755126  DecisionTreeClassifier(ccp_alpha=0, criterion=...
# 3           SVM    0.836639        SVC(kernel='poly', max_iter=139, tol=0.025)

# %%
scores
# Out:
# [{'model_name': 'Randomforest',
#   'best_score': 0.8541176470588235,
#   'best_estimator': RandomForestClassifier(ccp_alpha=0.0185, max_depth=15, min_samples_leaf=2,
#                          min_samples_split=5, n_estimators=400)},
#  {'model_name': 'logistic',
#   'best_score': 0.8539495798319328,
#   'best_estimator': LogisticRegression(max_iter=84, multi_class='ovr', solver='newton-cg', tol=0.5)},
#  {'model_name': 'D-tree',
#   'best_score': 0.755126050420168,
#   'best_estimator': DecisionTreeClassifier(ccp_alpha=0, criterion='entropy', max_features='sqrt',
#                          min_samples_leaf=2, splitter='random')},
#  {'model_name': 'SVM',
#   'best_score': 0.836638655462185,
#   'best_estimator': SVC(kernel='poly', max_iter=139, tol=0.025)}]

# %%
rf = RandomForestClassifier(max_depth=14)
rf.fit(X_train,Y_train)
y_pred = rf.predict(x_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8372093023255814

# %%
#logistic regression 
lr = LogisticRegression(C=0.25,max_iter=84,solver='newton-cg')
lr.fit(X_train,Y_train)
y_pred=lr.predict(x_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8372093023255814

# %%
#decision tree

dc= DecisionTreeClassifier(ccp_alpha=0,criterion='entropy',max_features='sqrt',min_samples_split=12)
dc.fit(X_train,Y_train)
y_pred=dc.predict(x_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.7674418604651163

# %%
print(metrics.classification_report(y_test,rf.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.67        12
#            1       0.85      0.94      0.89        31
#
#     accuracy                           0.84        43
#    macro avg       0.82      0.76      0.78        43
# weighted avg       0.83      0.84      0.83        43

# %%
cn= metrics.confusion_matrix(y_test,rf.predict(x_test))
sns.heatmap(cn,annot=True,cmap="plasma")
# Out:
# <Axes: >

# %% [markdown]
# MODEL TESTING

# %%
train
# Out:
#      degree_p  mba_p  hsc_p  gender  specialisation  ssc_p  hsc_b  workex
# 0       58.00  58.80  91.00       1               1  67.00      1       0
# 1       77.48  66.28  78.33       1               0  79.33      1       1
# 2       64.00  57.80  68.00       1               0  65.00      0       0
# 3       52.00  59.43  52.00       1               1  56.00      0       0
# 4       73.30  55.50  73.60       1               0  85.80      0       0
# ..        ...    ...    ...     ...             ...    ...    ...     ...
# 210     77.60  74.49  82.00       1               0  80.60      1       0
# 211     72.00  53.62  60.00       1               0  58.00      1       0
# 212     73.00  69.72  67.00       1               0  67.00      1       1
# 213     58.00  60.23  66.00       0               1  74.00      1       0
# 214     53.00  60.22  58.00       1               1  62.00      1       0
#
# [215 rows x 8 columns]

# %%
traindata= np.array(train)
predicted =[]
for i in range(len(traindata)):
    predicted.append(rf.predict([traindata[i]]))

predicted
# Out:
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
resultdf= train.copy()
resultdf['Actual']=np.array(test)
resultdf['Predicted']=np.array(predicted)
resultdf.head()
# Out:
#    degree_p  mba_p  hsc_p  gender  specialisation  ssc_p  hsc_b  workex  \
# 0     58.00  58.80  91.00       1               1  67.00      1       0
# 1     77.48  66.28  78.33       1               0  79.33      1       1
# 2     64.00  57.80  68.00       1               0  65.00      0       0
# 3     52.00  59.43  52.00       1               1  56.00      0       0
# 4     73.30  55.50  73.60       1               0  85.80      0       0
#
#    Actual  Predicted
# 0       1          1
# 1       1          1
# 2       1          1
# 3       0          0
# 4       1          1

# %%
resultdf['Actual'].value_counts()
# Out:
# Actual
# 1    148
# 0     67
# Name: count, dtype: int64

# %%
resultdf['Predicted'].value_counts()
# Out:
# Predicted
# 1    151
# 0     64
# Name: count, dtype: int64

# %% [markdown]
# PREDICTED PROBABILITIES

# %%
traindata= np.array(train)
predicted =[]
for i in range(len(traindata)):
    predicted.append(rf.predict_proba([traindata[i]]))

predicted
# Out:
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\HP\.conda\envs\campus\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
predicted[0][0],predicted[0][0][0],predicted[0][0][1]
# Out:
# (array([0.12, 0.88]), 0.12, 0.88)

# %%
resultdf['prob_not_getting_placed']=np.array([predicted[i][0][0] for i in range(len(predicted))])
resultdf['prob_getting_placed']=np.array([predicted[i][0][1] for i in range(len(predicted))])
resultdf
# Out:
#      degree_p  mba_p  hsc_p  gender  specialisation  ssc_p  hsc_b  workex  \
# 0       58.00  58.80  91.00       1               1  67.00      1       0
# 1       77.48  66.28  78.33       1               0  79.33      1       1
# 2       64.00  57.80  68.00       1               0  65.00      0       0
# 3       52.00  59.43  52.00       1               1  56.00      0       0
# 4       73.30  55.50  73.60       1               0  85.80      0       0
# ..        ...    ...    ...     ...             ...    ...    ...     ...
# 210     77.60  74.49  82.00       1               0  80.60      1       0
# 211     72.00  53.62  60.00       1               0  58.00      1       0
# 212     73.00  69.72  67.00       1               0  67.00      1       1
# 213     58.00  60.23  66.00       0               1  74.00      1       0
# 214     53.00  60.22  58.00       1               1  62.00      1       0
#
#      Actual  Predicted  prob_not_getting_placed  prob_getting_placed
# ...

# %%
#saving the model 

import pickle
file = open('placement_predictor.pkl','wb')
pickle.dump(rf,file)
file.close()
